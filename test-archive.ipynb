# %%
from toolbox.cSection import makeSampleCrossSection
from toolbox.patterns import Patterns
from toolbox.periodic import PeriodicTissue
from toolbox.minimization import FIREminimization
import matplotlib.pyplot as plt
from toolbox import stress
import os
import numpy as np
os.system("cp init/7_0/ 7_test/")
test_sample = "7_test/"

if os.path.isdir(test_sample):
    os.system("rm -r {}".format(test_sample))
os.system("cp -r init/{} {}".format(test_sample,test_sample))
dir = test_sample
file = "minimized.txt"


tissue = PeriodicTissue.from_config(dir,file)

# target_smiley_coordinates = [[3.5,7,5],[7,7,5],[3,5,5],[5,3,5],[8,4,5]]
target_smiley_coordinates = [[3.5,6,4],[5,6,4],[3,4,4],[5,3,4],[5.5,4,4]]

target_smiley_cells = []
for point in target_smiley_coordinates:
    target_smiley_cells.append(min(t_cells, key = lambda x: np.linalg.norm(t_cells[x].center_ - np.array(point))))

for cellID,cell in tissue.cells_.items():
    if cell.id_ in target_smiley_cells:
        cell.vtk_scalar_ = 1
    else:
        cell.vtk_scalar_  = 0
print(target_smiley_cells)
for cellID in target_smiley_cells:
    print(cellID, stress.calculate_max_shear_stress(tissue,cellID,COM_center=True))
# training_instance = Patterns.periodic_tissue(tissue)
makeSampleCrossSection(sample=tissue, center = np.array([4,4,4]),normal=[0,0,1])
# # print(training_instance._config.time_)

# %%
from toolbox.cSection import makeSampleCrossSection
from toolbox.patterns import Patterns
from toolbox.periodic import PeriodicTissue
import matplotlib.pyplot as plt
from toolbox import stress
import os
import numpy as np
test_sample = "8_0/"
if os.path.isdir(test_sample):
    os.system("rm -r {}".format(test_sample))
os.system("cp -r init/{} {}".format(test_sample,test_sample))
dir = test_sample
file = "minimized.txt"


tissue = PeriodicTissue.from_config(dir,file)
t_cells = {}

for cellID, cell in tissue.cells_.items():
    if cell.crossBoundary_:
        continue
    t_cells[cellID] = cell
# target_smiley_coordinates = [[3.5,7,5],[7,7,5],[3,5,5],[5,3,5],[8,4,5]]
target_smiley_coordinates = [[3.5,6,4],[5,6,4],[3,4,4],[5,3,4],[5.5,4,4]]

target_smiley_cells = []
for point in target_smiley_coordinates:
    target_smiley_cells.append(min(t_cells, key = lambda x: np.linalg.norm(t_cells[x].center_ - np.array(point))))

for cellID,cell in tissue.cells_.items():
    if cell.id_ in target_smiley_cells:
        cell.vtk_scalar_ = 1
    else:
        cell.vtk_scalar_  = 0
print(target_smiley_cells)
for cellID in target_smiley_cells:
    print(cellID, stress.calculate_max_shear_stress(tissue,cellID,COM_center=True))
# training_instance = Patterns.periodic_tissue(tissue)
makeSampleCrossSection(sample=tissue, center = np.array([4,4,4]),normal=[0,0,1])
# # print(training_instance._config.time_)
# Out:
# [11, 157, 494, 166, 378]
# 11 0.05609041663868575
# 157 0.13237028269787865
# 494 0.0752513633570635
# 166 0.045754469894436545
# 378 0.08968533588540861

# %%
from toolbox.cSection import makeSampleCrossSection
from toolbox.patterns import Patterns
from toolbox.periodic import PeriodicTissue
import matplotlib.pyplot as plt
import os
import numpy as np
test_sample = "8_0_5_1/"
if os.path.isdir(test_sample):
    os.system("rm -r {}".format(test_sample))
os.system("cp -r init/{} {}".format(test_sample,test_sample))
dir = test_sample
file = "minimized.txt"


tissue = PeriodicTissue.from_config(dir,file)
t_cells = {}

for cellID, cell in tissue.cells_.items():
    if cell.crossBoundary_:
        continue
    t_cells[cellID] = cell
# target_smiley_cells = [786, 408, 508, 283, 900]
target_smiley_cells = [11, 157, 494, 166, 378]

# 11 0.05609041663868575
# 157 0.13237028269787865
# 494 0.0752513633570635
# 166 0.045754469894436545
# 378 0.08968533588540861

training_instance = Patterns.periodic_tissue(tissue)
training_instance.edit_conf(kv = 10)
training_instance.minimize_config()

training_instance.set_target_cell_to_stress({
    11:0.06,
    157:0.13,
    494:0.08,
    166:0.05,
    378:0.09})
# training_instance.set_target_stresses({786:0.17,408:0.14,508:0.09,283:0.12,900:0.14})
# training_instance.set_target_stresses({
#     11:0.05609041663868575, 
#     157:0.13237028269787865, 
#     494:0.0752513633570635,
#     166:0.045754469894436545, 
#     378:0.08968533588540861})
# training_instance.set_target_stresses({
#     11:0.06,
#     157:0.13,
#     494:0.08,
#     166:0.05,
#     378:0.09})

# training_instance.set_iter_counter(0)
# training_instance.clamp_target_cells()
# training_instance.calculate_max_shear_stresses()

# print("Initial target cell stresses:")
# for cellID in training_instance._target_cells:
#     cell = training_instance._config.cells_[cellID]
#     print(cellID, cell.max_shear_stress_)
training_instance.set_tolerance(1e-7)
training_instance.run()
# training_instance.calculate_max_shear_stresses()
# print("Final target cell stresses:")
# for cellID in training_instance._target_cells:
#     cell = training_instance._config.cells_[cellID]
#     print(cellID, cell.max_shear_stress_)
# Out:
# Initialization start ...
#
# cellParameters.input not present or could not be processed.
# Proceeding minimization with homogeneous cell properties.
# Initial F_rms: 9.95661e-08
#    Minimization terminated:
#    Input is already minimized at FIRE_equilibrium_tolerance: 1e-07
# cellParameters.input does not exist
# Initial Cost: 5.40e-02
#
#
# ...
#
#
# Starting iteration: 0
#
#
# ...
#
#
# Number of modifiable cells: 512
#
#
# -------------------------------------
# Step 1: Evaluate and store the current (free state) areas of hidden (non-target) cells
#
#
# -------------------------------------
# Step 2: CLAMPING
# Clamping iteration 0
# Cell: 11, Final Target Stress: 0.06 Temporary Target Stress: 0.025167114571349458, Current stress: 0.1180548090477509, s0: 5.0
# cp: cannot stat '8_0_5_1/cellParameters.input': No such file or directory
# Cell: 157, Final Target Stress: 0.13 Temporary Target Stress: 0.08843983457407716, Current stress: 0.29803064198005935, s0: 5.0
# ...

# %%
from toolbox.cSection import makeSampleCrossSection
from toolbox.patterns import Patterns
from toolbox.periodic import PeriodicTissue
import matplotlib.pyplot as plt
import os
import numpy as np
test_sample = "8_0/"
if os.path.isdir(test_sample):
    os.system("rm -r {}".format(test_sample))
os.system("cp -r init/{} {}".format(test_sample,test_sample))
dir = test_sample
file = "minimized.txt"


tissue = PeriodicTissue.from_config(dir,file)
t_cells = {}

for cellID, cell in tissue.cells_.items():
    if cell.crossBoundary_:
        continue
    t_cells[cellID] = cell
# target_smiley_cells = [786, 408, 508, 283, 900]
target_smiley_cells = [494]

# 11 0.05609041663868575
# 157 0.13237028269787865
# 494 0.0752513633570635
# 166 0.045754469894436545
# 378 0.08968533588540861

training_instance = Patterns.periodic_tissue(tissue)
# training_instance.edit_conf(kv = 1)
training_instance.minimize_config()
training_instance.set_target_cells(target_smiley_cells)
# training_instance.set_target_stresses({786:0.17,408:0.14,508:0.09,283:0.12,900:0.14})
# training_instance.set_target_stresses({
#     11:0.05609041663868575, 
#     157:0.13237028269787865, 
#     494:0.0752513633570635,
#     166:0.045754469894436545, 
#     378:0.08968533588540861})
training_instance.set_target_stresses({
    494:0.08})

training_instance.set_iter_counter(0)
# training_instance.clamp_target_cells()
training_instance.calculate_max_shear_stresses()

print("Initial target cell stresses:")
for cellID in training_instance._target_cells:
    cell = training_instance._config.cells_[cellID]
    print(cellID, cell.max_shear_stress_)
training_instance.set_tolerance(1e-8)
training_instance.run()
training_instance.calculate_max_shear_stresses()
print("Final target cell stresses:")
for cellID in training_instance._target_cells:
    cell = training_instance._config.cells_[cellID]
    print(cellID, cell.max_shear_stress_)
# Out:
# Initialization start ...
# Number of vertices: 3046
# Maximum vertex ID: 10024
# Number of edges: 6092
# Maximum edge ID: 28197
# Number of polygons: 3558
# Maximum polygon ID: 5103
# Number of cells: 512
# Maximum cell ID: 511
# Number of polygons with two neighboring cells: 3558/3558
# time: 0 ~ 2000 ~ 0.005 ~ 0.05
# dump: vtk 100
# log: 100
# Average s0: 5.2
# Lth: 0.02 verbose: 0
# temperature: 0.0001
# kv: 10
# box: 8 8 8 periodic boundary condition: 1 1 1
#
# cellParameters.input not present or could not be processed.
# Proceeding minimization with homogeneous cell properties.
# Initial F_rms: 9.948e-08
#    Minimization terminated:
#    Input is already minimized at FIRE_equilibrium_tolerance: 1e-07
# cellParameters.input does not exist
# Initial target cell stresses:
# 494 0.0752513633570635
# Initial Cost: 2.25e-05
#
#
# ...
#
#
# Starting iteration: 0
#
#
# ...
#
#
# Number of modifiable cells: 512
# Target cells:  [494]
#
#
# -------------------------------------
# ...
