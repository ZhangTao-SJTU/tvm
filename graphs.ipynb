# %%
import numpy as np
import matplotlib.pyplot as plt
overdamped_time = np.array([0.00,100.00,200.00,300.00])
overdamped_F_rms = np.array([0.151480,0.024089,0.024376,0.024675])
FIRE_iterations = np.array([0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1728])
FIRE_F_rms = np.array([2.4650003e-02,1.9349483e-02,4.4095442e-03,1.6346471e-04,1.7870978e-05,2.3989238e-06,2.1266994e-06,1.9418191e-06,1.7840258e-06,1.6209753e-06,1.4426808e-06,1.2483954e-06,1.0418400e-06,8.2895465e-07,6.1687591e-07,4.1312401e-07,2.2398893e-07,5.0668447e-08,9.05912e-09])
overdamped_iterations = 200 * overdamped_time

for i, val in enumerate(FIRE_iterations):
    FIRE_iterations[i] = val + overdamped_iterations[-1] + 1
plt.scatter(overdamped_iterations, overdamped_F_rms, label = 'Overdamped', color='red')
plt.scatter(FIRE_iterations, FIRE_F_rms, label = 'FIRE', color = 'blue', alpha = 0.2)
plt.xlabel('Iterations')
plt.ylabel(r'$F_{rms}$')
plt.yscale('log')
plt.legend(loc = 'lower left')
plt.title(r'$s_0 = 4.8$')
# Out:
# Text(0.5, 1.0, '$s_0 = 4.8$')

# %%
overdamped_time = np.array([i*100 for i in range (21)])
overdamped_F_rms = np.array([3.267391,
 0.014096,
 0.013899,
 0.013766,
 0.013863,
 0.013841,
 0.014565,
 0.013878,
 0.013980,
 0.013499,
 0.013586,    
 0.013818,    
 0.013113,    
 0.013337,    
 0.012976, 
 0.014151, 
 0.012994,
 0.013595,
 0.013471,
 0.013313,
 0.012562])

overdamped_iterations = 200 * overdamped_time
FIRE_iterations = np.array([i*100 for i in range(11)]+[1728])
FIRE_F_rms = np.array([1.2765105e-02,
 4.3746387e-03,
 8.9390901e-04,
 9.8098531e-05,
 7.2282837e-05,
 3.3249252e-05,
 1.7260712e-06,
 6.8189738e-07,
 5.1904812e-07,
 2.7199752e-07,
 1.9270909e-08,
 9.06437e-09])
for i, val in enumerate(FIRE_iterations):
    FIRE_iterations[i] = val + overdamped_iterations[-1] + 1
plt.scatter(overdamped_iterations, overdamped_F_rms, label = 'Overdamped', color='red', alpha = 0.5)
plt.scatter(FIRE_iterations, FIRE_F_rms, label = 'FIRE', color = 'blue', alpha = 0.2)
plt.xlabel('Iterations')
plt.ylabel(r'$F_{rms}$')
plt.yscale('log')
plt.legend(loc = 'lower left')
plt.title(r'$s_0 = 5.8$')
# Out:
# Text(0.5, 1.0, '$s_0 = 5.8$')
